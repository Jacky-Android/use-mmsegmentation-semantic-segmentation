# %%
# !pip install -U openmim
# !mim install mmcv-full
# Out:
# Looking in indexes: https://pypi.doubanio.com/simple
# Collecting openmim
#   Downloading https://pypi.doubanio.com/packages/06/74/6354469b464671438b927417cdde470353d2fa3a8df67817d925c3c8f17a/openmim-0.3.2-py2.py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 288.9 kB/s eta 0:00:00a 0:00:01
# Collecting colorama
#   Downloading https://pypi.doubanio.com/packages/d1/d6/3965ed04c63042e047cb6a3e6ed1a63a35087b6a609aa3a15ed8ac56c221/colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting tabulate
#   Downloading https://pypi.doubanio.com/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: pip>=19.3 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from openmim) (22.2.2)
# Collecting rich
#   Downloading https://pypi.doubanio.com/packages/32/60/81ac2e7d1e3b861ab478a72e3b20fc91c4302acd2274822e493758941829/rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 kB 1.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Click in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from openmim) (8.1.3)
# Collecting model-index
#   Downloading https://pypi.doubanio.com/packages/0f/a6/4d4cbbef704f186d143e2859296a610a355992e4eae71582bd598093b36a/model_index-0.1.11-py3-none-any.whl (34 kB)
# Requirement already satisfied: requests in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from openmim) (2.28.1)
# Requirement already satisfied: pandas in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from openmim) (1.3.5)
# Requirement already satisfied: importlib-metadata in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from Click->openmim) (5.0.0)
# Collecting ordered-set
#   Downloading https://pypi.doubanio.com/packages/33/55/af02708f230eb77084a299d7b08175cff006dea4f2721074b92cdb0296c0/ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: markdown in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from model-index->openmim) (3.4.1)
# Requirement already satisfied: pyyaml in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from pandas->openmim) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from pandas->openmim) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from requests->openmim) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from requests->openmim) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from requests->openmim) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from requests->openmim) (2.1.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from rich->openmim) (2.13.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from rich->openmim) (4.4.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading https://pypi.doubanio.com/packages/b1/92/dfd892312d822f36c55366118b95d914e5f16de11044a27cf10a7d71bbbf/commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 242.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.5 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->openmim) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from importlib-metadata->Click->openmim) (3.9.0)
# Installing collected packages: commonmark, tabulate, rich, ordered-set, colorama, model-index, openmim
# Successfully installed colorama-0.4.6 commonmark-0.9.1 model-index-0.1.11 openmim-0.3.2 ordered-set-4.1.0 rich-12.6.0 tabulate-0.9.0
# /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Looking in indexes: https://pypi.doubanio.com/simple
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu116/torch1.12.0/index.html
# Collecting mmcv-full
#   Downloading https://download.openmmlab.com/mmcv/dist/cu116/torch1.12.0/mmcv_full-1.6.2-cp37-cp37m-manylinux1_x86_64.whl (40.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 MB 7.8 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: packaging in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmcv-full) (21.3)
# Requirement already satisfied: numpy in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmcv-full) (1.21.6)
# Collecting addict
#   Downloading https://pypi.doubanio.com/packages/6a/00/b08f23b7d7e1e14ce01419a467b583edbb93c6cdb8654e54a9cc579cd61f/addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: opencv-python>=3 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmcv-full) (4.6.0.66)
# Requirement already satisfied: Pillow in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmcv-full) (9.2.0)
# Requirement already satisfied: pyyaml in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmcv-full) (6.0)
# Collecting yapf
#   Downloading https://pypi.doubanio.com/packages/47/88/843c2e68f18a5879b4fbf37cb99fbabe1ffc4343b2e63191c8462235c008/yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from packaging->mmcv-full) (3.0.9)
# Installing collected packages: yapf, addict, mmcv-full
# Successfully installed addict-2.4.0 mmcv-full-1.6.2 yapf-0.32.0

# %%
# !git clone https://github.com/open-mmlab/mmsegmentation.git
# Out:
# Cloning into 'mmsegmentation'...
# remote: Enumerating objects: 12064, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 12064 (delta 72), reused 101 (delta 40), pack-reused 11894
# Receiving objects: 100% (12064/12064), 15.27 MiB | 4.58 MiB/s, done.
# Resolving deltas: 100% (8782/8782), done.

# %%
# %cd /home/rongjian/yolov7-main/wandb
# !git clone https://github.com/open-mmlab/mmcv.git
# %cd mmcv
# !pip install -r requirements.txt
# Out:
# /home/rongjian/yolov7-main/wandb
# Cloning into 'mmcv'...
# remote: Enumerating objects: 13775, done.
# remote: Counting objects: 100% (679/679), done.
# remote: Compressing objects: 100% (443/443), done.
# remote: Total 13775 (delta 366), reused 447 (delta 231), pack-reused 13096
# Receiving objects: 100% (13775/13775), 13.14 MiB | 5.48 MiB/s, done.
# Resolving deltas: 100% (9819/9819), done.
# /home/rongjian/yolov7-main/wandb/mmcv
# Looking in indexes: https://pypi.doubanio.com/simple
# Ignoring regex: markers 'sys_platform == "win32"' don't match your environment
# Collecting pytest-runner
#   Downloading https://pypi.doubanio.com/packages/42/7b/1cec26caae4bf44bb9911e1119d5d1a35171571e100b728a2ccd8719a3b1/pytest_runner-6.0.0-py3-none-any.whl (7.2 kB)
# Collecting ninja
#   Downloading https://pypi.doubanio.com/packages/48/d2/5c106c854b0f2366679747b2a9c5377cc59e03e2b80d72e41588d143abbc/ninja-1.10.2.4-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: psutil in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from -r requirements/optional.txt (line 2)) (5.9.3)
# Requirement already satisfied: addict in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 1)) (2.4.0)
# Requirement already satisfied: numpy in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 2)) (1.21.6)
# Requirement already satisfied: packaging in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 3)) (21.3)
# Requirement already satisfied: Pillow in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 4)) (9.2.0)
# Requirement already satisfied: pyyaml in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 5)) (6.0)
# Requirement already satisfied: yapf in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 7)) (0.32.0)
# Collecting coverage
#   Downloading https://pypi.doubanio.com/packages/0d/ef/8735875a8dc09e1c4e484a5436c8b4148731b70daccc6f203c50b05e7505/coverage-6.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.1/210.1 kB 1.9 MB/s eta 0:00:0000:0100:01
# Collecting lmdb
#   Downloading https://pypi.doubanio.com/packages/4d/cf/3230b1c9b0bec406abb85a9332ba5805bdd03a1d24025c6bbcfb8ed71539/lmdb-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 2.0 MB/s eta 0:00:0000:0100:01
# Collecting onnx
#   Downloading https://pypi.doubanio.com/packages/bf/c5/e8edd9bc58192ef964270e2f4600a02cd5e5d0958b81f7abe2ee0a604478/onnx-1.12.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 9.5 MB/s eta 0:00:00:00:0100:01
# Collecting onnxoptimizer
#   Downloading https://pypi.doubanio.com/packages/cf/e5/76d76e063b4b79a7761924f525f7895ab146dc1a9f4c1379342151a349b4/onnxoptimizer-0.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (602 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.8/602.8 kB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting onnxruntime>=1.8.0
#   Downloading https://pypi.doubanio.com/packages/81/6e/e42eb266f9e29d4fc680eae1407d0fca2166378f9b9f761a4626fade9fbe/onnxruntime-1.13.1-cp37-cp37m-manylinux_2_27_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 8.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: protobuf~=3.19.0 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from -r requirements/test.txt (line 6)) (3.19.6)
# Collecting pytest
#   Downloading https://pypi.doubanio.com/packages/67/68/a5eb36c3a8540594b6035e6cdae40c1ef1b6a2bfacbecc3d1a544583c078/pytest-7.2.0-py3-none-any.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.8/316.8 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Collecting PyTurboJPEG
#   Downloading https://pypi.doubanio.com/packages/49/c2/393921bd77f347dcdc90459969f2aa31b1dfb60f831d0f80dbbe5888a317/PyTurboJPEG-1.6.7.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from -r requirements/test.txt (line 9)) (1.7.3)
# Collecting tifffile
#   Downloading https://pypi.doubanio.com/packages/d8/38/85ae5ed77598ca90558c17a2f79ddaba33173b31cf8d8f545d34d9134f0d/tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from packaging->-r requirements/runtime.txt (line 3)) (3.0.9)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from onnx->-r requirements/test.txt (line 3)) (4.4.0)
# Collecting sympy
#   Downloading https://pypi.doubanio.com/packages/d0/04/66be21ceb305c66a4b326b0ae44cc4f027a43bc08cac204b48fb45bb3653/sympy-1.10.1-py3-none-any.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 8.8 MB/s eta 0:00:00:00:0100:01
# Collecting flatbuffers
#   Downloading https://pypi.doubanio.com/packages/f9/61/db094ced417900f2da2757451b7d3de0378d35ddbef79cc3384b31adbf2f/flatbuffers-22.9.24-py2.py3-none-any.whl (26 kB)
# Collecting coloredlogs
#   Downloading https://pypi.doubanio.com/packages/a7/06/3d6badcf13db419e25b07041d9c7b4a2c331d3f4e7134445ec5df57714cd/coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 812.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: importlib-metadata>=0.12 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from pytest->-r requirements/test.txt (line 7)) (5.0.0)
# Collecting pluggy<2.0,>=0.12
#   Using cached https://pypi.doubanio.com/packages/9e/01/f38e2ff29715251cf25532b9082a1589ab7e4f571ced434f98d0139336dc/pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting tomli>=1.0.0
#   Using cached https://pypi.doubanio.com/packages/97/75/10a9ebee3fd790d20926a90a2547f0bf78f371b2f13aa822c759680ca7b9/tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: attrs>=19.2.0 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from pytest->-r requirements/test.txt (line 7)) (22.1.0)
# Collecting iniconfig
#   Using cached https://pypi.doubanio.com/packages/9b/dd/b3c12c6d707058fa947864b67f0c4e0c39ef8610988d7baea9578f3c48f3/iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading https://pypi.doubanio.com/packages/de/4c/2854d9e3dcce78108126aa3634186a64ddbfd06d4d69af74954665529e52/exceptiongroup-1.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: zipp>=0.5 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->-r requirements/test.txt (line 7)) (3.9.0)
# Collecting humanfriendly>=9.1
#   Downloading https://pypi.doubanio.com/packages/f0/0f/310fb31e39e2d734ccaa2c0fb981ee41f7bd5056ce9bc29b2248bd569169/humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 1.5 MB/s eta 0:00:00ta 0:00:01
# Collecting mpmath>=0.19
#   Downloading https://pypi.doubanio.com/packages/d4/cf/3965bddbb4f1a61c49aacae0e78fd1fe36b5dc36c797b31f30cf07dcbbb7/mpmath-1.2.1-py3-none-any.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.6/532.6 kB 6.1 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: PyTurboJPEG
#   Building wheel for PyTurboJPEG (setup.py) ... done
#   Created wheel for PyTurboJPEG: filename=PyTurboJPEG-1.6.7-py3-none-any.whl size=12153 sha256=9bd132fdf0ee5b68b93e6d2d58362f4d73ee15690c50ae6c7f97b583b54d21df
#   Stored in directory: /home/rongjian/.cache/pip/wheels/28/f8/fd/aa0f853b7b381f6c310ff2760bdec9c834b6161fd263ba9b00
# Successfully built PyTurboJPEG
# Installing collected packages: ninja, mpmath, lmdb, iniconfig, flatbuffers, tomli, tifffile, sympy, PyTurboJPEG, pytest-runner, onnx, humanfriendly, exceptiongroup, coverage, pluggy, onnxoptimizer, coloredlogs, pytest, onnxruntime
# Successfully installed PyTurboJPEG-1.6.7 coloredlogs-15.0.1 coverage-6.5.0 exceptiongroup-1.0.0 flatbuffers-22.9.24 humanfriendly-10.0 iniconfig-1.1.1 lmdb-1.3.0 mpmath-1.2.1 ninja-1.10.2.4 onnx-1.12.0 onnxoptimizer-0.3.1 onnxruntime-1.13.1 pluggy-1.0.0 pytest-7.2.0 pytest-runner-6.0.0 sympy-1.10.1 tifffile-2021.11.2 tomli-2.0.1

# %%
# %cd /home/rongjian/yolov7-main/wandb/mmsegmentation
# !pip install -v -e .
# Out:
# /home/rongjian/yolov7-main/wandb/mmsegmentation
# Using pip 22.2.2 from /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages/pip (python 3.7)
# Looking in indexes: https://pypi.doubanio.com/simple
# Obtaining file:///home/rongjian/yolov7-main/wandb/mmsegmentation
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-pyk9c09d/mmsegmentation.egg-info
#   writing /tmp/pip-pip-egg-info-pyk9c09d/mmsegmentation.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-pyk9c09d/mmsegmentation.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-pyk9c09d/mmsegmentation.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-pyk9c09d/mmsegmentation.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-pyk9c09d/mmsegmentation.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-pyk9c09d/mmsegmentation.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching 'mmseg/.mim/model-index.yml'
#   warning: no files found matching '*.py' under directory 'mmseg/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmseg/.mim/configs'
#   warning: no files found matching '*.py' under directory 'mmseg/.mim/tools'
#   warning: no files found matching '*.sh' under directory 'mmseg/.mim/tools'
#   adding license file 'LICENSE'
#   adding license file 'LICENSES.md'
#   writing manifest file '/tmp/pip-pip-egg-info-pyk9c09d/mmsegmentation.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmsegmentation==0.29.0) (3.5.3)
# Collecting mmcls>=0.20.1
#   Downloading https://pypi.doubanio.com/packages/dd/70/0a4058f419c62428df3f8bfaf567e450f090c29699b056d06eba2b43d8bd/mmcls-0.24.0-py2.py3-none-any.whl (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.8/647.8 kB 4.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmsegmentation==0.29.0) (1.21.6)
# Requirement already satisfied: packaging in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from mmsegmentation==0.29.0) (21.3)
# Collecting prettytable
#   Downloading https://pypi.doubanio.com/packages/5b/c9/4e7dbae5054c5bbaed9e7aa7a78e1ceff003d0b0699318e5d6993a0a10c9/prettytable-3.4.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: pillow>=6.2.0 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.0) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.0) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from matplotlib->mmsegmentation==0.29.0) (2.8.2)
# Requirement already satisfied: importlib-metadata in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from prettytable->mmsegmentation==0.29.0) (5.0.0)
# Requirement already satisfied: wcwidth in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from prettytable->mmsegmentation==0.29.0) (0.2.5)
# Requirement already satisfied: typing-extensions in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->mmsegmentation==0.29.0) (4.4.0)
# Requirement already satisfied: six>=1.5 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation==0.29.0) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages (from importlib-metadata->prettytable->mmsegmentation==0.29.0) (3.9.0)
# Installing collected packages: prettytable, mmcls, mmsegmentation
#   Running setup.py develop for mmsegmentation
#     Running command python setup.py develop
#     running develop
#     running egg_info
#     creating mmsegmentation.egg-info
#     writing mmsegmentation.egg-info/PKG-INFO
#     writing dependency_links to mmsegmentation.egg-info/dependency_links.txt
#     writing requirements to mmsegmentation.egg-info/requires.txt
#     writing top-level names to mmsegmentation.egg-info/top_level.txt
#     writing manifest file 'mmsegmentation.egg-info/SOURCES.txt'
#     reading manifest file 'mmsegmentation.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     adding license file 'LICENSE'
#     adding license file 'LICENSES.md'
#     writing manifest file 'mmsegmentation.egg-info/SOURCES.txt'
#     running build_ext
#     Creating /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages/mmsegmentation.egg-link (link to .)
#     Adding mmsegmentation 0.29.0 to easy-install.pth file
#
#     Installed /home/rongjian/yolov7-main/wandb/mmsegmentation
#     /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages/setuptools/command/easy_install.py:147: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#       EasyInstallDeprecationWarning,
#     /home/rongjian/miniconda3/envs/yolov7/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       setuptools.SetuptoolsDeprecationWarning,
# Successfully installed mmcls-0.24.0 mmsegmentation-0.29.0 prettytable-3.4.1

# %%
# %cd /home/rongjian/yolov7-main/wandb
# %mkdir datas
# %mkdir datas/ann
# %mkdir datas/ann/training
# %mkdir datas/ann/validation
# %mkdir datas/images
# %mkdir datas/images/training
# %mkdir datas/images/validation
# Out:
# /home/rongjian/yolov7-main/wandb

# %%
import os
from shutil import copy
from sys import exit
import tqdm
path = "/home/rongjian/yolov7-main/wandb/dataset/semantic_drone_dataset/original_images" #文件夹目录
path_map = "/home/rongjian/yolov7-main/wandb/dataset/semantic_drone_dataset/label_images_semantic"
files= os.listdir(path) #得到文件夹下的所有文件名称

for i in range(len(files)):
    if i<360:
        copy(path+'/'+files[i], '/home/rongjian/yolov7-main/wandb/datas/images/training')
        copy(path_map+'/'+files[i][:-4]+'.png', '/home/rongjian/yolov7-main/wandb/datas/ann/training')
    elif 359<i<400:
        copy(path+'/'+files[i], '/home/rongjian/yolov7-main/wandb/datas/images/validation')
        copy(path_map+'/'+files[i][:-4]+'.png', '/home/rongjian/yolov7-main/wandb/datas/ann/validation')

# %%
# %cd /home/rongjian/yolov7-main/wandb/mmsegmentation
# Out:
# /home/rongjian/yolov7-main/wandb/mmsegmentation

# %%
# %%writefile configs/_base_/models/danet_r50-d8.py
norm_cfg = dict(type='SyncBN', requires_grad=True)
model = dict(
    type='EncoderDecoder',
    pretrained='open-mmlab://resnet50_v1c',
    backbone=dict(
        type='ResNetV1c',
        depth=50,
        num_stages=4,
        out_indices=(0, 1, 2, 3),
        dilations=(1, 1, 2, 4),
        strides=(1, 2, 1, 1),
        norm_cfg=norm_cfg,
        norm_eval=False,
        style='pytorch',
        contract_dilation=True),
    decode_head=dict(
        type='DAHead',
        in_channels=2048,
        in_index=3,
        channels=512,
        pam_channels=64,
        dropout_ratio=0.1,
        num_classes=23,
        norm_cfg=norm_cfg,
        align_corners=False,
        loss_decode=dict(
            type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
    auxiliary_head=dict(
        type='FCNHead',
        in_channels=1024,
        in_index=2,
        channels=256,
        num_convs=1,
        concat_input=False,
        dropout_ratio=0.1,
        num_classes=23,
        norm_cfg=norm_cfg,
        align_corners=False,
        loss_decode=dict(
            type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
    # model training and testing settings
    train_cfg=dict(),
    test_cfg=dict(mode='whole'))
# Out:
# Overwriting configs/_base_/models/danet_r50-d8.py

# %%
# %%writefile mmseg/datasets/my_dataset.py
import mmcv
from mmcv.utils import print_log

from ..utils import get_root_logger
from .builder import DATASETS
from .custom import CustomDataset


@DATASETS.register_module()

class Mydataset(CustomDataset):
   
    CLASSES = ('unlabeled', 'paved-area', 'dirt', 'grass', 'gravel', 'water',
               'rocks', 'pool', 'vegetation', 'roof', 'wall', 'window', 'door', 'fence', 
               'fence-pole', 'person', 'dog', 'car', 'bicycle', 'tree', 'bald-tree', 'ar-marker', 
               'obstacle')

    PALETTE = [[0, 0, 0], [128, 64, 128], [130, 76, 0], [0, 102, 0], [112, 103, 87], [28, 42, 168], 
               [48, 41, 30], [0, 50, 89], [107, 142, 35], [70, 70, 70], [102, 102, 156], [254, 228, 12], 
               [254, 148, 12], [190, 153, 153], [153, 153, 153], [255, 22, 96], [102, 51, 0], [9, 143, 150], 
               [119, 11, 32], [51, 51, 0], [190, 250, 190], [112, 150, 146], [2, 135, 115]]


    def __init__(self, **kwargs):
        super(Mydataset, self).__init__(
            img_suffix='.jpg',
            seg_map_suffix='.png',
            ignore_index=255,
            **kwargs)
        assert self.file_client.exists(self.img_dir)

    def load_annotations(self,
                         img_dir,
                         img_suffix,
                         ann_dir,
                         seg_map_suffix=None,
                         split=None):
        

        img_infos = []
        if split is not None:
            with open(split) as f:
                for line in f:
                    name = line.strip()
                    img_info = dict(filename=name + img_suffix)
                    if ann_dir is not None:
                        ann_name = name 
                        seg_map = ann_name + seg_map_suffix
                        img_info['ann'] = dict(seg_map=seg_map)
                    img_infos.append(img_info)
        else:
            for img in mmcv.scandir(img_dir, img_suffix, recursive=True):
                img_info = dict(filename=img)
                if ann_dir is not None:
                    seg_img = img
                    seg_map = seg_img.replace(
                        img_suffix,  seg_map_suffix)
                    img_info['ann'] = dict(seg_map=seg_map)
                img_infos.append(img_info)

        print_log(f'Loaded {len(img_infos)} images', logger=get_root_logger())
        return img_infos
# Out:
# Writing mmseg/datasets/my_dataset.py

# %%
# %%writefile configs/_base_/datasets/my_dataset.py
dataset_type = 'Mydataset' #上一步中你定义的数据集的名字
data_root = '/home/rongjian/yolov7-main/wandb/datas' #数据集存储路径
img_norm_cfg = dict(
    mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
crop_size = (768,768)
train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(type='Resize', img_scale=(768,768), ratio_range=(0.5, 2.0)),
    dict(type='RandomCrop', crop_size=crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PhotoMetricDistortion'),
    dict(type='Normalize', **img_norm_cfg),
    dict(type='Pad', size=crop_size, pad_val=0, seg_pad_val=255),
    dict(type='DefaultFormatBundle'),
    dict(type='Collect', keys=['img', 'gt_semantic_seg']),
]
test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(
        type='MultiScaleFlipAug',
        img_scale=(768,768),
        # img_ratios=[0.5, 0.75, 1.0, 1.25, 1.5, 1.75],
        flip=False,
        transforms=[
            dict(type='Resize', keep_ratio=True),
            dict(type='RandomFlip'),
            dict(type='Normalize', **img_norm_cfg),
            dict(type='ImageToTensor', keys=['img']),
            dict(type='Collect', keys=['img']),
        ])
]
data = dict(
    samples_per_gpu=5,
    workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        data_root=data_root,
        img_dir='images/training', #训练图像路径
        ann_dir='ann/training', #训练mask路径
        pipeline=train_pipeline),
    val=dict(
        type=dataset_type,
        data_root=data_root,
        img_dir='images/validation',  #验证图像路径
        ann_dir='ann/validation',  #验证mask路径
        pipeline=test_pipeline),
    #我的数据集没有测试集，和验证集用同一路径，问题不大
    test=dict(
        type=dataset_type,
        data_root=data_root,
        img_dir='images/validation',  #测试图像路径
        ann_dir='ann/validation',  #测试mask路径
        pipeline=test_pipeline))
# Out:
# Overwriting configs/_base_/datasets/my_dataset.py

# %%
# %%writefile mmseg/datasets/__init__.py
from .ade import ADE20KDataset
from .builder import DATASETS, PIPELINES, build_dataloader, build_dataset
from .chase_db1 import ChaseDB1Dataset
from .cityscapes import CityscapesDataset
from .coco_stuff import COCOStuffDataset
from .custom import CustomDataset
from .dark_zurich import DarkZurichDataset
from .dataset_wrappers import (ConcatDataset, MultiImageMixDataset,
                               RepeatDataset)
from .drive import DRIVEDataset
from .hrf import HRFDataset
from .isaid import iSAIDDataset
from .isprs import ISPRSDataset
from .loveda import LoveDADataset
from .night_driving import NightDrivingDataset
from .pascal_context import PascalContextDataset, PascalContextDataset59
from .potsdam import PotsdamDataset
from .stare import STAREDataset
from .voc import PascalVOCDataset
import sys
sys.path.append('..')
from .my_dataset import Mydataset
__all__ = [
    'CustomDataset', 'build_dataloader', 'ConcatDataset', 'RepeatDataset',
    'DATASETS', 'build_dataset', 'PIPELINES', 'CityscapesDataset',
    'PascalVOCDataset', 'ADE20KDataset', 'PascalContextDataset',
    'PascalContextDataset59', 'ChaseDB1Dataset', 'DRIVEDataset', 'HRFDataset',
    'STAREDataset', 'DarkZurichDataset', 'NightDrivingDataset',
    'COCOStuffDataset', 'LoveDADataset', 'MultiImageMixDataset',
    'iSAIDDataset', 'ISPRSDataset', 'PotsdamDataset','Mydataset'
]
# Out:
# Overwriting mmseg/datasets/__init__.py

# %%
# %%writefile configs/_base_/schedules/schedule_20k.py
optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
optimizer_config = dict()
# learning policy
lr_config = dict(policy='poly', power=0.9, min_lr=1e-4, by_epoch=False)
runner = dict(type='EpochBasedRunner', max_epochs=100) #按epoch的方式进行迭代
checkpoint_config = dict(by_epoch=True, interval=50) #每多少次迭代保存一次模型
evaluation = dict(interval=5, metric='mIoU')  # 每多少次迭代计算一次指标
# Out:
# Overwriting configs/_base_/schedules/schedule_20k.py

# %%
# %%writefile configs/pspnet/pspnet_r50-d8_512x512_160k_ade20k.py 
_base_ = [
    '../_base_/models/danet_r50-d8.py',
    '../_base_/datasets/my_dataset.py', '../_base_/default_runtime.py',
    '../_base_/schedules/schedule_20k.py'
]
model = dict(
    decode_head=dict(num_classes=23), auxiliary_head=dict(num_classes=23))
# Out:
# Overwriting configs/pspnet/pspnet_r50-d8_512x512_160k_ade20k.py

# %%
# !python tools/train.py configs/pspnet/pspnet_r50-d8_512x512_160k_ade20k.py
# Out:
# 2022-10-29 12:27:07,220 - mmseg - INFO - Multi-processing start method is `None`
# 2022-10-29 12:27:07,220 - mmseg - INFO - OpenCV num_threads is `32
# 2022-10-29 12:27:07,248 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.13 (default, Oct 18 2022, 18:57:03) [GCC 11.2.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 3090
# CUDA_HOME: /usr/local/cuda
# NVCC: Cuda compilation tools, release 11.6, V11.6.124
# GCC: gcc (GCC) 8.5.0 20210514 (Red Hat 8.5.0-10)
# PyTorch: 1.12.1+cu116
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
# TorchVision: 0.13.1+cu116
# OpenCV: 4.6.0
# MMCV: 1.6.2
# MMCV Compiler: GCC 9.3
# MMCV CUDA Compiler: 11.6
# MMSegmentation: 0.29.0+6db0935
# ------------------------------------------------------------
#
# 2022-10-29 12:27:07,249 - mmseg - INFO - Distributed training: False
# 2022-10-29 12:27:07,411 - mmseg - INFO - Config:
# norm_cfg = dict(type='SyncBN', requires_grad=True)
# model = dict(
#     type='EncoderDecoder',
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 2, 4),
#         strides=(1, 2, 1, 1),
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     decode_head=dict(
#         type='DAHead',
#         in_channels=2048,
#         in_index=3,
#         channels=512,
#         pam_channels=64,
#         dropout_ratio=0.1,
#         num_classes=23,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=1024,
#         in_index=2,
#         channels=256,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=23,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# dataset_type = 'Mydataset'
# data_root = '/home/rongjian/yolov7-main/wandb/datas'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# crop_size = (768, 768)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(type='Resize', img_scale=(768, 768), ratio_range=(0.5, 2.0)),
#     dict(type='RandomCrop', crop_size=(768, 768), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size=(768, 768), pad_val=0, seg_pad_val=255),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_semantic_seg'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(768, 768),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=5,
#     workers_per_gpu=2,
#     train=dict(
#         type='Mydataset',
#         data_root='/home/rongjian/yolov7-main/wandb/datas',
#         img_dir='images/training',
#         ann_dir='ann/training',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(type='Resize', img_scale=(768, 768), ratio_range=(0.5, 2.0)),
#             dict(type='RandomCrop', crop_size=(768, 768), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size=(768, 768), pad_val=0, seg_pad_val=255),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_semantic_seg'])
#         ]),
#     val=dict(
#         type='Mydataset',
#         data_root='/home/rongjian/yolov7-main/wandb/datas',
#         img_dir='images/validation',
#         ann_dir='ann/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(768, 768),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='Mydataset',
#         data_root='/home/rongjian/yolov7-main/wandb/datas',
#         img_dir='images/validation',
#         ann_dir='ann/validation',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(768, 768),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# log_config = dict(
#     interval=50, hooks=[dict(type='TextLoggerHook', by_epoch=False)])
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# cudnn_benchmark = True
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optimizer_config = dict()
# lr_config = dict(policy='poly', power=0.9, min_lr=0.0001, by_epoch=False)
# runner = dict(type='EpochBasedRunner', max_epochs=100)
# checkpoint_config = dict(by_epoch=True, interval=50)
# evaluation = dict(interval=5, metric='mIoU')
# work_dir = './work_dirs/pspnet_r50-d8_512x512_160k_ade20k'
# gpu_ids = [0]
# auto_resume = False
#
# 2022-10-29 12:27:07,411 - mmseg - INFO - Set random seed to 565601320, deterministic: False
# /home/rongjian/yolov7-main/wandb/mmsegmentation/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# /home/rongjian/yolov7-main/wandb/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:236: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# 2022-10-29 12:27:07,691 - mmseg - INFO - initialize ResNetV1c with init_cfg {'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet50_v1c'}
# 2022-10-29 12:27:07,692 - mmcv - INFO - load model from: open-mmlab://resnet50_v1c
# 2022-10-29 12:27:07,692 - mmcv - INFO - load checkpoint from openmmlab path: open-mmlab://resnet50_v1c
# 2022-10-29 12:27:07,739 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2022-10-29 12:27:07,752 - mmseg - INFO - initialize DAHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# 2022-10-29 12:27:07,847 - mmseg - INFO - initialize FCNHead with init_cfg {'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# tools/train.py:207: UserWarning: SyncBN is only supported with DDP. To be compatible with DP, we convert SyncBN to BN. Please use dist_train.sh which can avoid this error.
#   'SyncBN is only supported with DDP. To be compatible with DP, '
# 2022-10-29 12:27:07,855 - mmseg - INFO - EncoderDecoder(
#   (backbone): ResNetV1c(
#     (stem): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): _BatchNormXd(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): _BatchNormXd(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (7): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): _BatchNormXd(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet50_v1c'}
#   (decode_head): DAHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(512, 23, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (pam_in_conv): ConvModule(
#       (conv): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#     (pam): PAM(
#       (key_project): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (query_project): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (value_project): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#       (gamma): Scale()
#     )
#     (pam_out_conv): ConvModule(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#     (pam_conv_seg): Conv2d(512, 23, kernel_size=(1, 1), stride=(1, 1))
#     (cam_in_conv): ConvModule(
#       (conv): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#     (cam): CAM(
#       (gamma): Scale()
#     )
#     (cam_out_conv): ConvModule(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): _BatchNormXd(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#     (cam_conv_seg): Conv2d(512, 23, kernel_size=(1, 1), stride=(1, 1))
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(256, 23, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )
# 2022-10-29 12:27:07,860 - mmseg - INFO - Loaded 360 images
# 2022-10-29 12:27:08,688 - mmseg - INFO - Loaded 40 images
# 2022-10-29 12:27:08,688 - mmseg - INFO - Start running, host: rongjian@rtx3090, work_dir: /home/rongjian/yolov7-main/wandb/mmsegmentation/work_dirs/pspnet_r50-d8_512x512_160k_ade20k
# 2022-10-29 12:27:08,688 - mmseg - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) PolyLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2022-10-29 12:27:08,688 - mmseg - INFO - workflow: [('train', 1)], max: 100 epochs
# 2022-10-29 12:27:08,689 - mmseg - INFO - Checkpoints will be saved to /home/rongjian/yolov7-main/wandb/mmsegmentation/work_dirs/pspnet_r50-d8_512x512_160k_ade20k by HardDiskBackend.
# 2022-10-29 12:27:56,897 - mmseg - INFO - Iter [50/7200]	lr: 9.939e-03, eta: 1:54:45, time: 0.963, data_time: 0.096, memory: 18994, decode.pam_cam.loss_ce: 1.3694, decode.pam_cam.acc_seg: 52.2286, decode.pam.loss_ce: 1.3052, decode.pam.acc_seg: 55.5443, decode.cam.loss_ce: 1.3142, decode.cam.acc_seg: 54.6211, aux.loss_ce: 0.6476, aux.acc_seg: 44.1226, loss: 4.6364
# 2022-10-29 12:28:41,638 - mmseg - INFO - Iter [100/7200]	lr: 9.877e-03, eta: 1:53:05, time: 0.948, data_time: 0.186, memory: 18994, decode.pam_cam.loss_ce: 0.9510, decode.pam_cam.acc_seg: 66.9144, decode.pam.loss_ce: 0.8447, decode.pam.acc_seg: 69.1411, decode.cam.loss_ce: 0.8495, decode.cam.acc_seg: 69.0245, aux.loss_ce: 0.3974, aux.acc_seg: 67.5340, loss: 3.0426
# 2022-10-29 12:29:26,193 - mmseg - INFO - Iter [150/7200]	lr: 9.815e-03, eta: 2:10:20, time: 1.416, data_time: 0.651, memory: 18994, decode.pam_cam.loss_ce: 0.8594, decode.pam_cam.acc_seg: 68.0973, decode.pam.loss_ce: 0.7304, decode.pam.acc_seg: 70.7174, decode.cam.loss_ce: 0.7344, decode.cam.acc_seg: 70.9876, aux.loss_ce: 0.3324, aux.acc_seg: 68.8086, loss: 2.6566
# 2022-10-29 12:30:07,653 - mmseg - INFO - Iter [200/7200]	lr: 9.753e-03, eta: 2:01:14, time: 0.829, data_time: 0.060, memory: 18994, decode.pam_cam.loss_ce: 0.8480, decode.pam_cam.acc_seg: 67.5727, decode.pam.loss_ce: 0.7924, decode.pam.acc_seg: 69.4535, decode.cam.loss_ce: 0.7866, decode.cam.acc_seg: 69.6046, aux.loss_ce: 0.3685, aux.acc_seg: 66.1013, loss: 2.7955
# 2022-10-29 12:30:52,396 - mmseg - INFO - Iter [250/7200]	lr: 9.691e-03, eta: 1:57:47, time: 0.928, data_time: 0.157, memory: 18994, decode.pam_cam.loss_ce: 0.7129, decode.pam_cam.acc_seg: 70.5198, decode.pam.loss_ce: 0.6681, decode.pam.acc_seg: 71.8730, decode.cam.loss_ce: 0.6693, decode.cam.acc_seg: 71.9601, aux.loss_ce: 0.3288, aux.acc_seg: 67.5398, loss: 2.3790
# 2022-10-29 12:31:37,281 - mmseg - INFO - Iter [300/7200]	lr: 9.629e-03, eta: 1:59:07, time: 1.131, data_time: 0.362, memory: 18994, decode.pam_cam.loss_ce: 0.5373, decode.pam_cam.acc_seg: 76.2969, decode.pam.loss_ce: 0.5069, decode.pam.acc_seg: 78.2617, decode.cam.loss_ce: 0.5117, decode.cam.acc_seg: 77.8695, aux.loss_ce: 0.2688, aux.acc_seg: 72.6692, loss: 1.8245
# 2022-10-29 12:32:18,668 - mmseg - INFO - Iter [350/7200]	lr: 9.567e-03, eta: 1:54:52, time: 0.828, data_time: 0.056, memory: 18994, decode.pam_cam.loss_ce: 0.5846, decode.pam_cam.acc_seg: 76.2175, decode.pam.loss_ce: 0.5531, decode.pam.acc_seg: 77.0320, decode.cam.loss_ce: 0.5568, decode.cam.acc_seg: 76.7638, aux.loss_ce: 0.2950, aux.acc_seg: 70.7585, loss: 1.9895
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 40/40, 8.1 task/s, elapsed: 5s, ETA:     0s2022-10-29 12:32:48,430 - mmseg - INFO - per class results:
# 2022-10-29 12:32:48,432 - mmseg - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | unlabeled  |  0.0  |  0.0  |
# | paved-area | 60.97 | 68.21 |
# |    dirt    | 29.61 |  41.9 |
# |   grass    | 50.81 | 93.88 |
# |   gravel   | 23.95 | 26.44 |
# |   water    | 28.04 | 29.44 |
# |   rocks    |  8.73 |  9.38 |
# |    pool    |  25.6 | 26.03 |
# | vegetation | 47.62 | 94.04 |
# |    roof    | 69.48 | 78.27 |
# |    wall    | 22.12 | 33.87 |
# |   window   |  0.69 |  0.7  |
# |    door    |  0.0  |  0.0  |
# |   fence    |  0.0  |  0.0  |
# | fence-pole |  0.0  |  0.0  |
# |   person   | 40.42 |  63.7 |
# |    dog     |  0.0  |  0.0  |
# |    car     | 51.01 | 82.94 |
# |  bicycle   | 13.76 | 25.02 |
# |    tree    | 16.42 | 18.89 |
# | bald-tree  | 39.33 | 46.19 |
# | ar-marker  | 54.16 | 56.25 |
# |  obstacle  | 32.49 |  37.0 |
# +------------+-------+-------+
# 2022-10-29 12:32:48,432 - mmseg - INFO - Summary:
# 2022-10-29 12:32:48,432 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 65.39 | 26.75 | 36.18 |
# +-------+-------+-------+
# 2022-10-29 12:32:48,433 - mmseg - INFO - Iter(val) [40]	aAcc: 0.6539, mIoU: 0.2675, mAcc: 0.3618, IoU.unlabeled: 0.0000, IoU.paved-area: 0.6097, IoU.dirt: 0.2961, IoU.grass: 0.5081, IoU.gravel: 0.2395, IoU.water: 0.2804, IoU.rocks: 0.0873, IoU.pool: 0.2560, IoU.vegetation: 0.4762, IoU.roof: 0.6948, IoU.wall: 0.2212, IoU.window: 0.0069, IoU.door: 0.0000, IoU.fence: 0.0000, IoU.fence-pole: 0.0000, IoU.person: 0.4042, IoU.dog: 0.0000, IoU.car: 0.5101, IoU.bicycle: 0.1376, IoU.tree: 0.1642, IoU.bald-tree: 0.3933, IoU.ar-marker: 0.5416, IoU.obstacle: 0.3249, Acc.unlabeled: 0.0000, Acc.paved-area: 0.6821, Acc.dirt: 0.4190, Acc.grass: 0.9388, Acc.gravel: 0.2644, Acc.water: 0.2944, Acc.rocks: 0.0938, Acc.pool: 0.2603, Acc.vegetation: 0.9404, Acc.roof: 0.7827, Acc.wall: 0.3387, Acc.window: 0.0070, Acc.door: 0.0000, Acc.fence: 0.0000, Acc.fence-pole: 0.0000, Acc.person: 0.6370, Acc.dog: 0.0000, Acc.car: 0.8294, Acc.bicycle: 0.2502, Acc.tree: 0.1889, Acc.bald-tree: 0.4619, Acc.ar-marker: 0.5625, Acc.obstacle: 0.3700
# 2022-10-29 12:33:24,965 - mmseg - INFO - Iter [400/7200]	lr: 9.505e-03, eta: 1:52:41, time: 0.912, data_time: 0.142, memory: 18994, decode.pam_cam.loss_ce: 0.5778, decode.pam_cam.acc_seg: 76.0002, decode.pam.loss_ce: 0.5395, decode.pam.acc_seg: 77.3047, decode.cam.loss_ce: 0.5389, decode.cam.acc_seg: 77.3843, aux.loss_ce: 0.2809, aux.acc_seg: 72.0307, loss: 1.9372
# 2022-10-29 12:34:09,776 - mmseg - INFO - Iter [450/7200]	lr: 9.443e-03, eta: 1:52:12, time: 1.022, data_time: 0.249, memory: 18994, decode.pam_cam.loss_ce: 0.5123, decode.pam_cam.acc_seg: 79.7685, decode.pam.loss_ce: 0.4669, decode.pam.acc_seg: 81.4736, decode.cam.loss_ce: 0.4693, decode.cam.acc_seg: 81.3911, aux.loss_ce: 0.2729, aux.acc_seg: 75.0050, loss: 1.7214
# 2022-10-29 12:34:51,397 - mmseg - INFO - Iter [500/7200]	lr: 9.380e-03, eta: 1:49:32, time: 0.832, data_time: 0.060, memory: 18994, decode.pam_cam.loss_ce: 0.5303, decode.pam_cam.acc_seg: 79.4325, decode.pam.loss_ce: 0.4962, decode.pam.acc_seg: 80.5445, decode.cam.loss_ce: 0.4984, decode.cam.acc_seg: 80.4800, aux.loss_ce: 0.2637, aux.acc_seg: 75.0584, loss: 1.7885
# 2022-10-29 12:35:36,483 - mmseg - INFO - Iter [550/7200]	lr: 9.318e-03, eta: 1:48:00, time: 0.909, data_time: 0.137, memory: 18994, decode.pam_cam.loss_ce: 0.5230, decode.pam_cam.acc_seg: 79.0629, decode.pam.loss_ce: 0.4858, decode.pam.acc_seg: 80.3363, decode.cam.loss_ce: 0.4867, decode.cam.acc_seg: 80.2596, aux.loss_ce: 0.2551, aux.acc_seg: 74.8307, loss: 1.7506
# 2022-10-29 12:36:21,904 - mmseg - INFO - Iter [600/7200]	lr: 9.256e-03, eta: 1:47:19, time: 0.990, data_time: 0.216, memory: 18994, decode.pam_cam.loss_ce: 0.4489, decode.pam_cam.acc_seg: 81.0724, decode.pam.loss_ce: 0.4352, decode.pam.acc_seg: 81.5577, decode.cam.loss_ce: 0.4454, decode.cam.acc_seg: 81.3255, aux.loss_ce: 0.2421, aux.acc_seg: 75.5531, loss: 1.5716
# 2022-10-29 12:37:07,265 - mmseg - INFO - Iter [650/7200]	lr: 9.193e-03, eta: 2:00:11, time: 2.604, data_time: 1.830, memory: 18994, decode.pam_cam.loss_ce: 0.4707, decode.pam_cam.acc_seg: 80.7571, decode.pam.loss_ce: 0.4381, decode.pam.acc_seg: 82.3489, decode.cam.loss_ce: 0.4406, decode.cam.acc_seg: 81.6462, aux.loss_ce: 0.2343, aux.acc_seg: 75.0699, loss: 1.5837
# 2022-10-29 12:37:49,375 - mmseg - INFO - Iter [700/7200]	lr: 9.131e-03, eta: 1:57:16, time: 0.842, data_time: 0.068, memory: 18994, decode.pam_cam.loss_ce: 0.3879, decode.pam_cam.acc_seg: 83.6551, decode.pam.loss_ce: 0.3739, decode.pam.acc_seg: 84.2341, decode.cam.loss_ce: 0.3778, decode.cam.acc_seg: 84.1282, aux.loss_ce: 0.2160, aux.acc_seg: 78.9024, loss: 1.3556
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 40/40, 8.6 task/s, elapsed: 5s, ETA:     0s2022-10-29 12:38:28,354 - mmseg - INFO - per class results:
# 2022-10-29 12:38:28,355 - mmseg - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | unlabeled  |  0.0  |  0.0  |
# | paved-area | 89.28 | 96.91 |
# |    dirt    | 44.51 |  50.9 |
# |   grass    | 90.12 | 94.57 |
# |   gravel   | 70.82 | 84.46 |
# |   water    | 86.19 | 95.87 |
# |   rocks    | 31.16 | 39.95 |
# |    pool    | 76.88 | 88.79 |
# | vegetation | 65.96 | 77.05 |
# |    roof    | 81.84 | 84.75 |
# |    wall    |  43.0 |  67.6 |
# |   window   | 18.77 | 24.58 |
# |    door    |  0.0  |  0.0  |
# |   fence    | 22.21 | 31.44 |
# | fence-pole |  0.0  |  0.0  |
# |   person   | 45.88 |  54.4 |
# |    dog     |  0.0  |  0.0  |
# |    car     | 85.98 | 90.87 |
# |  bicycle   | 23.59 | 32.26 |
# |    tree    | 46.04 | 73.93 |
# | bald-tree  | 61.86 |  76.8 |
# | ar-marker  | 79.56 | 84.69 |
# |  obstacle  | 54.34 | 69.17 |
# +------------+-------+-------+
# 2022-10-29 12:38:28,355 - mmseg - INFO - Summary:
# 2022-10-29 12:38:28,356 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 86.64 | 48.61 | 57.35 |
# +-------+-------+-------+
# 2022-10-29 12:38:28,356 - mmseg - INFO - Iter(val) [40]	aAcc: 0.8664, mIoU: 0.4861, mAcc: 0.5735, IoU.unlabeled: 0.0000, IoU.paved-area: 0.8928, IoU.dirt: 0.4451, IoU.grass: 0.9012, IoU.gravel: 0.7082, IoU.water: 0.8619, IoU.rocks: 0.3116, IoU.pool: 0.7688, IoU.vegetation: 0.6596, IoU.roof: 0.8184, IoU.wall: 0.4300, IoU.window: 0.1877, IoU.door: 0.0000, IoU.fence: 0.2221, IoU.fence-pole: 0.0000, IoU.person: 0.4588, IoU.dog: 0.0000, IoU.car: 0.8598, IoU.bicycle: 0.2359, IoU.tree: 0.4604, IoU.bald-tree: 0.6186, IoU.ar-marker: 0.7956, IoU.obstacle: 0.5434, Acc.unlabeled: 0.0000, Acc.paved-area: 0.9691, Acc.dirt: 0.5090, Acc.grass: 0.9457, Acc.gravel: 0.8446, Acc.water: 0.9587, Acc.rocks: 0.3995, Acc.pool: 0.8879, Acc.vegetation: 0.7705, Acc.roof: 0.8475, Acc.wall: 0.6760, Acc.window: 0.2458, Acc.door: 0.0000, Acc.fence: 0.3144, Acc.fence-pole: 0.0000, Acc.person: 0.5440, Acc.dog: 0.0000, Acc.car: 0.9087, Acc.bicycle: 0.3226, Acc.tree: 0.7393, Acc.bald-tree: 0.7680, Acc.ar-marker: 0.8469, Acc.obstacle: 0.6917
# 2022-10-29 12:38:56,832 - mmseg - INFO - Iter [750/7200]	lr: 9.068e-03, eta: 1:55:24, time: 0.947, data_time: 0.180, memory: 18994, decode.pam_cam.loss_ce: 0.3353, decode.pam_cam.acc_seg: 85.4163, decode.pam.loss_ce: 0.3315, decode.pam.acc_seg: 85.7815, decode.cam.loss_ce: 0.3334, decode.cam.acc_seg: 85.6461, aux.loss_ce: 0.1967, aux.acc_seg: 80.2655, loss: 1.1968
# 2022-10-29 12:39:42,238 - mmseg - INFO - Iter [800/7200]	lr: 9.006e-03, eta: 1:55:51, time: 1.275, data_time: 0.504, memory: 18994, decode.pam_cam.loss_ce: 0.4121, decode.pam_cam.acc_seg: 82.4892, decode.pam.loss_ce: 0.3641, decode.pam.acc_seg: 84.3854, decode.cam.loss_ce: 0.3645, decode.cam.acc_seg: 84.3473, aux.loss_ce: 0.1888, aux.acc_seg: 80.9271, loss: 1.3295
# 2022-10-29 12:40:24,146 - mmseg - INFO - Iter [850/7200]	lr: 8.943e-03, eta: 1:53:24, time: 0.838, data_time: 0.065, memory: 18994, decode.pam_cam.loss_ce: 0.3597, decode.pam_cam.acc_seg: 84.0084, decode.pam.loss_ce: 0.3403, decode.pam.acc_seg: 84.8350, decode.cam.loss_ce: 0.3399, decode.cam.acc_seg: 84.8128, aux.loss_ce: 0.1914, aux.acc_seg: 79.7853, loss: 1.2313
# 2022-10-29 12:41:09,570 - mmseg - INFO - Iter [900/7200]	lr: 8.880e-03, eta: 1:51:42, time: 0.934, data_time: 0.161, memory: 18994, decode.pam_cam.loss_ce: 0.3563, decode.pam_cam.acc_seg: 85.1758, decode.pam.loss_ce: 0.3376, decode.pam.acc_seg: 85.8709, decode.cam.loss_ce: 0.3390, decode.cam.acc_seg: 85.6781, aux.loss_ce: 0.1899, aux.acc_seg: 81.1095, loss: 1.2229
# 2022-10-29 12:41:54,992 - mmseg - INFO - Iter [950/7200]	lr: 8.817e-03, eta: 1:50:55, time: 1.082, data_time: 0.309, memory: 18994, decode.pam_cam.loss_ce: 0.2981, decode.pam_cam.acc_seg: 87.3455, decode.pam.loss_ce: 0.2979, decode.pam.acc_seg: 87.4945, decode.cam.loss_ce: 0.3022, decode.cam.acc_seg: 87.4119, aux.loss_ce: 0.1855, aux.acc_seg: 81.4944, loss: 1.0837
# 2022-10-29 12:42:36,895 - mmseg - INFO - Exp name: pspnet_r50-d8_512x512_160k_ade20k.py
# 2022-10-29 12:42:36,895 - mmseg - INFO - Iter [1000/7200]	lr: 8.755e-03, eta: 1:48:51, time: 0.838, data_time: 0.061, memory: 18994, decode.pam_cam.loss_ce: 0.2805, decode.pam_cam.acc_seg: 87.6866, decode.pam.loss_ce: 0.2759, decode.pam.acc_seg: 88.0044, decode.cam.loss_ce: 0.2803, decode.cam.acc_seg: 87.8655, aux.loss_ce: 0.1681, aux.acc_seg: 83.1996, loss: 1.0049
# 2022-10-29 12:43:22,503 - mmseg - INFO - Iter [1050/7200]	lr: 8.692e-03, eta: 1:47:21, time: 0.926, data_time: 0.153, memory: 18994, decode.pam_cam.loss_ce: 0.3018, decode.pam_cam.acc_seg: 86.9659, decode.pam.loss_ce: 0.2990, decode.pam.acc_seg: 87.1274, decode.cam.loss_ce: 0.3012, decode.cam.acc_seg: 87.0888, aux.loss_ce: 0.1763, aux.acc_seg: 82.1494, loss: 1.0783
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 40/40, 8.6 task/s, elapsed: 5s, ETA:     0s2022-10-29 12:44:09,987 - mmseg - INFO - per class results:
# 2022-10-29 12:44:09,988 - mmseg - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | unlabeled  |  0.0  |  0.0  |
# | paved-area | 91.48 | 95.61 |
# |    dirt    | 42.02 | 45.52 |
# |   grass    | 92.45 | 95.83 |
# |   gravel   | 72.21 | 93.45 |
# |   water    | 85.72 | 93.38 |
# |   rocks    |  39.2 |  59.0 |
# |    pool    | 88.26 |  98.0 |
# | vegetation | 72.64 | 85.17 |
# |    roof    | 82.18 | 86.82 |
# |    wall    | 54.23 | 72.21 |
# |   window   | 21.87 | 22.69 |
# |    door    |  0.0  |  0.0  |
# |   fence    | 27.81 | 35.19 |
# | fence-pole |  0.0  |  0.0  |
# |   person   | 52.24 |  63.6 |
# |    dog     |  0.0  |  0.0  |
# |    car     | 87.53 | 93.92 |
# |  bicycle   | 37.79 | 50.98 |
# |    tree    | 59.06 | 75.14 |
# | bald-tree  | 67.16 | 83.89 |
# | ar-marker  | 79.67 | 88.53 |
# |  obstacle  | 55.71 | 74.58 |
# +------------+-------+-------+
# 2022-10-29 12:44:09,988 - mmseg - INFO - Summary:
# 2022-10-29 12:44:09,988 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 88.62 | 52.58 | 61.46 |
# +-------+-------+-------+
# 2022-10-29 12:44:09,988 - mmseg - INFO - Iter(val) [40]	aAcc: 0.8862, mIoU: 0.5258, mAcc: 0.6146, IoU.unlabeled: 0.0000, IoU.paved-area: 0.9148, IoU.dirt: 0.4202, IoU.grass: 0.9245, IoU.gravel: 0.7221, IoU.water: 0.8572, IoU.rocks: 0.3920, IoU.pool: 0.8826, IoU.vegetation: 0.7264, IoU.roof: 0.8218, IoU.wall: 0.5423, IoU.window: 0.2187, IoU.door: 0.0000, IoU.fence: 0.2781, IoU.fence-pole: 0.0000, IoU.person: 0.5224, IoU.dog: 0.0000, IoU.car: 0.8753, IoU.bicycle: 0.3779, IoU.tree: 0.5906, IoU.bald-tree: 0.6716, IoU.ar-marker: 0.7967, IoU.obstacle: 0.5571, Acc.unlabeled: 0.0000, Acc.paved-area: 0.9561, Acc.dirt: 0.4552, Acc.grass: 0.9583, Acc.gravel: 0.9345, Acc.water: 0.9338, Acc.rocks: 0.5900, Acc.pool: 0.9800, Acc.vegetation: 0.8517, Acc.roof: 0.8682, Acc.wall: 0.7221, Acc.window: 0.2269, Acc.door: 0.0000, Acc.fence: 0.3519, Acc.fence-pole: 0.0000, Acc.person: 0.6360, Acc.dog: 0.0000, Acc.car: 0.9392, Acc.bicycle: 0.5098, Acc.tree: 0.7514, Acc.bald-tree: 0.8389, Acc.ar-marker: 0.8853, Acc.obstacle: 0.7458
# 2022-10-29 12:44:30,479 - mmseg - INFO - Iter [1100/7200]	lr: 8.629e-03, eta: 1:46:22, time: 1.021, data_time: 0.254, memory: 18994, decode.pam_cam.loss_ce: 0.2676, decode.pam_cam.acc_seg: 88.9183, decode.pam.loss_ce: 0.2623, decode.pam.acc_seg: 89.1231, decode.cam.loss_ce: 0.2705, decode.cam.acc_seg: 88.8350, aux.loss_ce: 0.1707, aux.acc_seg: 83.5918, loss: 0.9711
# 2022-10-29 12:45:12,804 - mmseg - INFO - Iter [1150/7200]	lr: 8.566e-03, eta: 1:44:37, time: 0.846, data_time: 0.074, memory: 18994, decode.pam_cam.loss_ce: 0.2486, decode.pam_cam.acc_seg: 89.3873, decode.pam.loss_ce: 0.2480, decode.pam.acc_seg: 89.4710, decode.cam.loss_ce: 0.2525, decode.cam.acc_seg: 89.3539, aux.loss_ce: 0.1553, aux.acc_seg: 84.6102, loss: 0.9044
# 2022-10-29 12:45:57,988 - mmseg - INFO - Iter [1200/7200]	lr: 8.503e-03, eta: 1:43:12, time: 0.907, data_time: 0.135, memory: 18994, decode.pam_cam.loss_ce: 0.2512, decode.pam_cam.acc_seg: 88.7101, decode.pam.loss_ce: 0.2506, decode.pam.acc_seg: 88.7981, decode.cam.loss_ce: 0.2508, decode.cam.acc_seg: 88.8506, aux.loss_ce: 0.1526, aux.acc_seg: 84.0452, loss: 0.9051
# 2022-10-29 12:46:43,314 - mmseg - INFO - Iter [1250/7200]	lr: 8.440e-03, eta: 1:42:08, time: 0.978, data_time: 0.204, memory: 18994, decode.pam_cam.loss_ce: 0.2580, decode.pam_cam.acc_seg: 88.7551, decode.pam.loss_ce: 0.2576, decode.pam.acc_seg: 88.9329, decode.cam.loss_ce: 0.2593, decode.cam.acc_seg: 88.9448, aux.loss_ce: 0.1573, aux.acc_seg: 84.2266, loss: 0.9322
# 2022-10-29 12:47:28,414 - mmseg - INFO - Iter [1300/7200]	lr: 8.377e-03, eta: 1:43:49, time: 1.703, data_time: 0.931, memory: 18994, decode.pam_cam.loss_ce: 0.2121, decode.pam_cam.acc_seg: 88.6711, decode.pam.loss_ce: 0.2110, decode.pam.acc_seg: 88.9112, decode.cam.loss_ce: 0.2159, decode.cam.acc_seg: 88.7627, aux.loss_ce: 0.1309, aux.acc_seg: 83.7632, loss: 0.7699
# 2022-10-29 12:48:10,128 - mmseg - INFO - Iter [1350/7200]	lr: 8.314e-03, eta: 1:42:08, time: 0.834, data_time: 0.061, memory: 18994, decode.pam_cam.loss_ce: 0.3005, decode.pam_cam.acc_seg: 86.8564, decode.pam.loss_ce: 0.2918, decode.pam.acc_seg: 87.1662, decode.cam.loss_ce: 0.2917, decode.cam.acc_seg: 87.2163, aux.loss_ce: 0.1608, aux.acc_seg: 83.4628, loss: 1.0448
# 2022-10-29 12:48:55,509 - mmseg - INFO - Iter [1400/7200]	lr: 8.251e-03, eta: 1:40:55, time: 0.949, data_time: 0.174, memory: 18994, decode.pam_cam.loss_ce: 0.3292, decode.pam_cam.acc_seg: 85.8151, decode.pam.loss_ce: 0.3150, decode.pam.acc_seg: 86.4820, decode.cam.loss_ce: 0.3161, decode.cam.acc_seg: 86.3471, aux.loss_ce: 0.1756, aux.acc_seg: 82.0344, loss: 1.1358
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 40/40, 8.8 task/s, elapsed: 5s, ETA:     0s2022-10-29 12:49:50,874 - mmseg - INFO - per class results:
# 2022-10-29 12:49:50,875 - mmseg - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | unlabeled  |  0.0  |  0.0  |
# | paved-area | 82.21 | 89.14 |
# |    dirt    | 53.32 |  68.9 |
# |   grass    | 91.33 | 95.99 |
# |   gravel   |  57.7 | 91.54 |
# |   water    | 80.98 | 96.24 |
# |   rocks    | 22.47 | 24.03 |
# |    pool    | 91.95 |  99.2 |
# | vegetation |  64.3 | 69.65 |
# |    roof    | 86.42 | 92.17 |
# |    wall    | 47.57 | 53.42 |
# |   window   |  40.5 | 56.72 |
# |    door    |  0.0  |  0.0  |
# |   fence    | 29.68 | 40.79 |
# | fence-pole |  0.0  |  0.0  |
# |   person   | 54.44 |  70.8 |
# |    dog     |  0.0  |  0.0  |
# |    car     | 78.48 | 95.99 |
# |  bicycle   | 38.33 | 62.11 |
# |    tree    | 49.55 |  80.7 |
# | bald-tree  | 59.38 | 67.95 |
# | ar-marker  | 81.23 | 89.35 |
# |  obstacle  | 62.05 | 72.08 |
# +------------+-------+-------+
# 2022-10-29 12:49:50,875 - mmseg - INFO - Summary:
# 2022-10-29 12:49:50,875 - mmseg - INFO -
# +-------+-------+------+
# |  aAcc |  mIoU | mAcc |
# +-------+-------+------+
# | 84.93 | 50.95 | 61.6 |
# +-------+-------+------+
# 2022-10-29 12:49:50,875 - mmseg - INFO - Iter(val) [40]	aAcc: 0.8493, mIoU: 0.5095, mAcc: 0.6160, IoU.unlabeled: 0.0000, IoU.paved-area: 0.8221, IoU.dirt: 0.5332, IoU.grass: 0.9133, IoU.gravel: 0.5770, IoU.water: 0.8098, IoU.rocks: 0.2247, IoU.pool: 0.9195, IoU.vegetation: 0.6430, IoU.roof: 0.8642, IoU.wall: 0.4757, IoU.window: 0.4050, IoU.door: 0.0000, IoU.fence: 0.2968, IoU.fence-pole: 0.0000, IoU.person: 0.5444, IoU.dog: 0.0000, IoU.car: 0.7848, IoU.bicycle: 0.3833, IoU.tree: 0.4955, IoU.bald-tree: 0.5938, IoU.ar-marker: 0.8123, IoU.obstacle: 0.6205, Acc.unlabeled: 0.0000, Acc.paved-area: 0.8914, Acc.dirt: 0.6890, Acc.grass: 0.9599, Acc.gravel: 0.9154, Acc.water: 0.9624, Acc.rocks: 0.2403, Acc.pool: 0.9920, Acc.vegetation: 0.6965, Acc.roof: 0.9217, Acc.wall: 0.5342, Acc.window: 0.5672, Acc.door: 0.0000, Acc.fence: 0.4079, Acc.fence-pole: 0.0000, Acc.person: 0.7080, Acc.dog: 0.0000, Acc.car: 0.9599, Acc.bicycle: 0.6211, Acc.tree: 0.8070, Acc.bald-tree: 0.6795, Acc.ar-marker: 0.8935, Acc.obstacle: 0.7208
# 2022-10-29 12:50:02,832 - mmseg - INFO - Iter [1450/7200]	lr: 8.187e-03, eta: 1:40:32, time: 1.189, data_time: 0.422, memory: 18994, decode.pam_cam.loss_ce: 0.2402, decode.pam_cam.acc_seg: 88.8976, decode.pam.loss_ce: 0.2355, decode.pam.acc_seg: 89.1413, decode.cam.loss_ce: 0.2409, decode.cam.acc_seg: 89.0691, aux.loss_ce: 0.1368, aux.acc_seg: 85.3716, loss: 0.8533
# 2022-10-29 12:50:44,055 - mmseg - INFO - Iter [1500/7200]	lr: 8.124e-03, eta: 1:38:57, time: 0.824, data_time: 0.054, memory: 18994, decode.pam_cam.loss_ce: 0.2671, decode.pam_cam.acc_seg: 88.6780, decode.pam.loss_ce: 0.2636, decode.pam.acc_seg: 88.9165, decode.cam.loss_ce: 0.2679, decode.cam.acc_seg: 88.8341, aux.loss_ce: 0.1608, aux.acc_seg: 84.0277, loss: 0.9595
# 2022-10-29 12:51:29,397 - mmseg - INFO - Iter [1550/7200]	lr: 8.061e-03, eta: 1:37:45, time: 0.931, data_time: 0.158, memory: 18994, decode.pam_cam.loss_ce: 0.2342, decode.pam_cam.acc_seg: 89.2768, decode.pam.loss_ce: 0.2265, decode.pam.acc_seg: 89.6918, decode.cam.loss_ce: 0.2290, decode.cam.acc_seg: 89.6081, aux.loss_ce: 0.1328, aux.acc_seg: 85.9884, loss: 0.8226
# ...
# 2022-10-29 14:04:11,677 - mmseg - INFO - Iter [6150/7200]	lr: 1.852e-03, eta: 0:18:01, time: 0.961, data_time: 0.195, memory: 18994, decode.pam_cam.loss_ce: 0.1053, decode.pam_cam.acc_seg: 94.7241, decode.pam.loss_ce: 0.1075, decode.pam.acc_seg: 94.7310, decode.cam.loss_ce: 0.1095, decode.cam.acc_seg: 94.5660, aux.loss_ce: 0.0761, aux.acc_seg: 91.8447, loss: 0.3984
# 2022-10-29 14:04:57,210 - mmseg - INFO - Iter [6200/7200]	lr: 1.777e-03, eta: 0:17:11, time: 1.299, data_time: 0.528, memory: 18994, decode.pam_cam.loss_ce: 0.1023, decode.pam_cam.acc_seg: 95.6307, decode.pam.loss_ce: 0.1038, decode.pam.acc_seg: 95.6231, decode.cam.loss_ce: 0.1073, decode.cam.acc_seg: 95.4375, aux.loss_ce: 0.0731, aux.acc_seg: 93.1938, loss: 0.3865
# 2022-10-29 14:05:39,102 - mmseg - INFO - Iter [6250/7200]	lr: 1.701e-03, eta: 0:16:18, time: 0.838, data_time: 0.064, memory: 18994, decode.pam_cam.loss_ce: 0.1048, decode.pam_cam.acc_seg: 94.8937, decode.pam.loss_ce: 0.1072, decode.pam.acc_seg: 94.8193, decode.cam.loss_ce: 0.1084, decode.cam.acc_seg: 94.7675, aux.loss_ce: 0.0744, aux.acc_seg: 92.2256, loss: 0.3948
# 2022-10-29 14:06:24,666 - mmseg - INFO - Iter [6300/7200]	lr: 1.625e-03, eta: 0:15:26, time: 0.940, data_time: 0.167, memory: 18994, decode.pam_cam.loss_ce: 0.1033, decode.pam_cam.acc_seg: 94.4616, decode.pam.loss_ce: 0.1061, decode.pam.acc_seg: 94.3652, decode.cam.loss_ce: 0.1068, decode.cam.acc_seg: 94.3077, aux.loss_ce: 0.0704, aux.acc_seg: 91.6916, loss: 0.3866
# 2022-10-29 14:07:09,996 - mmseg - INFO - Iter [6350/7200]	lr: 1.549e-03, eta: 0:14:35, time: 1.072, data_time: 0.300, memory: 18994, decode.pam_cam.loss_ce: 0.1081, decode.pam_cam.acc_seg: 94.5566, decode.pam.loss_ce: 0.1101, decode.pam.acc_seg: 94.5329, decode.cam.loss_ce: 0.1118, decode.cam.acc_seg: 94.4022, aux.loss_ce: 0.0726, aux.acc_seg: 92.0130, loss: 0.4026
# 2022-10-29 14:07:51,977 - mmseg - INFO - Iter [6400/7200]	lr: 1.472e-03, eta: 0:13:42, time: 0.840, data_time: 0.066, memory: 18994, decode.pam_cam.loss_ce: 0.1002, decode.pam_cam.acc_seg: 94.9099, decode.pam.loss_ce: 0.1027, decode.pam.acc_seg: 94.8137, decode.cam.loss_ce: 0.1039, decode.cam.acc_seg: 94.7740, aux.loss_ce: 0.0722, aux.acc_seg: 92.0787, loss: 0.3790
# 2022-10-29 14:08:37,123 - mmseg - INFO - Iter [6450/7200]	lr: 1.395e-03, eta: 0:12:50, time: 0.914, data_time: 0.142, memory: 18994, decode.pam_cam.loss_ce: 0.1036, decode.pam_cam.acc_seg: 94.9105, decode.pam.loss_ce: 0.1057, decode.pam.acc_seg: 94.8614, decode.cam.loss_ce: 0.1077, decode.cam.acc_seg: 94.7683, aux.loss_ce: 0.0749, aux.acc_seg: 92.0659, loss: 0.3919
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 40/40, 8.5 task/s, elapsed: 5s, ETA:     0s2022-10-29 14:09:24,744 - mmseg - INFO - per class results:
# 2022-10-29 14:09:24,745 - mmseg - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | unlabeled  |  0.13 |  0.13 |
# | paved-area | 95.25 | 97.87 |
# |    dirt    | 53.27 | 66.67 |
# |   grass    | 93.12 | 96.49 |
# |   gravel   | 80.94 | 91.37 |
# |   water    | 88.45 | 95.54 |
# |   rocks    | 54.37 | 68.44 |
# |    pool    | 96.23 | 97.91 |
# | vegetation | 74.91 | 85.15 |
# |    roof    | 91.97 | 94.81 |
# |    wall    | 70.17 | 83.13 |
# |   window   | 68.25 |  81.8 |
# |    door    |  0.0  |  0.0  |
# |   fence    | 49.88 | 60.07 |
# | fence-pole |  0.0  |  0.0  |
# |   person   | 68.97 | 83.91 |
# |    dog     |  52.0 | 60.18 |
# |    car     | 92.15 | 96.76 |
# |  bicycle   | 49.45 | 66.67 |
# |    tree    | 67.87 | 84.54 |
# | bald-tree  | 71.16 | 84.79 |
# | ar-marker  | 84.86 | 93.98 |
# |  obstacle  | 73.85 | 84.23 |
# +------------+-------+-------+
# 2022-10-29 14:09:24,745 - mmseg - INFO - Summary:
# 2022-10-29 14:09:24,745 - mmseg - INFO -
# +-------+-------+------+
# |  aAcc |  mIoU | mAcc |
# +-------+-------+------+
# | 92.33 | 64.23 | 72.8 |
# +-------+-------+------+
# 2022-10-29 14:09:24,745 - mmseg - INFO - Iter(val) [40]	aAcc: 0.9233, mIoU: 0.6423, mAcc: 0.7280, IoU.unlabeled: 0.0013, IoU.paved-area: 0.9525, IoU.dirt: 0.5327, IoU.grass: 0.9312, IoU.gravel: 0.8094, IoU.water: 0.8845, IoU.rocks: 0.5437, IoU.pool: 0.9623, IoU.vegetation: 0.7491, IoU.roof: 0.9197, IoU.wall: 0.7017, IoU.window: 0.6825, IoU.door: 0.0000, IoU.fence: 0.4988, IoU.fence-pole: 0.0000, IoU.person: 0.6897, IoU.dog: 0.5200, IoU.car: 0.9215, IoU.bicycle: 0.4945, IoU.tree: 0.6787, IoU.bald-tree: 0.7116, IoU.ar-marker: 0.8486, IoU.obstacle: 0.7385, Acc.unlabeled: 0.0013, Acc.paved-area: 0.9787, Acc.dirt: 0.6667, Acc.grass: 0.9649, Acc.gravel: 0.9137, Acc.water: 0.9554, Acc.rocks: 0.6844, Acc.pool: 0.9791, Acc.vegetation: 0.8515, Acc.roof: 0.9481, Acc.wall: 0.8313, Acc.window: 0.8180, Acc.door: 0.0000, Acc.fence: 0.6007, Acc.fence-pole: 0.0000, Acc.person: 0.8391, Acc.dog: 0.6018, Acc.car: 0.9676, Acc.bicycle: 0.6667, Acc.tree: 0.8454, Acc.bald-tree: 0.8479, Acc.ar-marker: 0.9398, Acc.obstacle: 0.8423
# 2022-10-29 14:09:44,937 - mmseg - INFO - Iter [6500/7200]	lr: 1.317e-03, eta: 0:11:59, time: 1.006, data_time: 0.242, memory: 18994, decode.pam_cam.loss_ce: 0.1048, decode.pam_cam.acc_seg: 94.8132, decode.pam.loss_ce: 0.1072, decode.pam.acc_seg: 94.7484, decode.cam.loss_ce: 0.1082, decode.cam.acc_seg: 94.7069, aux.loss_ce: 0.0732, aux.acc_seg: 92.2084, loss: 0.3935
# 2022-10-29 14:10:27,002 - mmseg - INFO - Iter [6550/7200]	lr: 1.238e-03, eta: 0:11:06, time: 0.841, data_time: 0.071, memory: 18994, decode.pam_cam.loss_ce: 0.0998, decode.pam_cam.acc_seg: 95.0750, decode.pam.loss_ce: 0.1022, decode.pam.acc_seg: 95.0078, decode.cam.loss_ce: 0.1036, decode.cam.acc_seg: 94.9458, aux.loss_ce: 0.0721, aux.acc_seg: 92.3865, loss: 0.3777
# 2022-10-29 14:11:12,688 - mmseg - INFO - Iter [6600/7200]	lr: 1.159e-03, eta: 0:10:15, time: 0.917, data_time: 0.145, memory: 18994, decode.pam_cam.loss_ce: 0.0998, decode.pam_cam.acc_seg: 94.9884, decode.pam.loss_ce: 0.1027, decode.pam.acc_seg: 94.8944, decode.cam.loss_ce: 0.1034, decode.cam.acc_seg: 94.8410, aux.loss_ce: 0.0712, aux.acc_seg: 92.2748, loss: 0.3771
# 2022-10-29 14:11:58,159 - mmseg - INFO - Iter [6650/7200]	lr: 1.080e-03, eta: 0:09:23, time: 0.980, data_time: 0.210, memory: 18994, decode.pam_cam.loss_ce: 0.1059, decode.pam_cam.acc_seg: 95.0006, decode.pam.loss_ce: 0.1087, decode.pam.acc_seg: 94.9209, decode.cam.loss_ce: 0.1105, decode.cam.acc_seg: 94.8501, aux.loss_ce: 0.0776, aux.acc_seg: 92.1803, loss: 0.4027
# 2022-10-29 14:12:43,419 - mmseg - INFO - Iter [6700/7200]	lr: 9.993e-04, eta: 0:08:35, time: 1.755, data_time: 0.983, memory: 18994, decode.pam_cam.loss_ce: 0.0809, decode.pam_cam.acc_seg: 96.2026, decode.pam.loss_ce: 0.0834, decode.pam.acc_seg: 96.1487, decode.cam.loss_ce: 0.0843, decode.cam.acc_seg: 96.1458, aux.loss_ce: 0.0679, aux.acc_seg: 93.5774, loss: 0.3165
# 2022-10-29 14:13:25,070 - mmseg - INFO - Iter [6750/7200]	lr: 9.181e-04, eta: 0:07:42, time: 0.833, data_time: 0.058, memory: 18994, decode.pam_cam.loss_ce: 0.1040, decode.pam_cam.acc_seg: 94.8733, decode.pam.loss_ce: 0.1063, decode.pam.acc_seg: 94.8062, decode.cam.loss_ce: 0.1083, decode.cam.acc_seg: 94.7239, aux.loss_ce: 0.0755, aux.acc_seg: 91.9332, loss: 0.3942
# 2022-10-29 14:14:10,809 - mmseg - INFO - Iter [6800/7200]	lr: 8.360e-04, eta: 0:06:51, time: 0.955, data_time: 0.183, memory: 18994, decode.pam_cam.loss_ce: 0.0989, decode.pam_cam.acc_seg: 95.2402, decode.pam.loss_ce: 0.1014, decode.pam.acc_seg: 95.1585, decode.cam.loss_ce: 0.1030, decode.cam.acc_seg: 95.1163, aux.loss_ce: 0.0727, aux.acc_seg: 92.5595, loss: 0.3760
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 40/40, 8.6 task/s, elapsed: 5s, ETA:     0s2022-10-29 14:15:06,909 - mmseg - INFO - per class results:
# 2022-10-29 14:15:06,910 - mmseg - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | unlabeled  |  0.12 |  0.13 |
# | paved-area | 95.19 |  97.6 |
# |    dirt    | 52.63 |  67.6 |
# |   grass    | 93.03 | 96.41 |
# |   gravel   | 80.34 | 91.46 |
# |   water    | 87.95 | 93.28 |
# |   rocks    | 56.16 | 72.92 |
# |    pool    | 96.42 | 98.53 |
# | vegetation | 75.17 | 85.92 |
# |    roof    | 91.75 | 94.43 |
# |    wall    | 70.82 | 83.22 |
# |   window   | 67.85 | 81.87 |
# |    door    |  0.0  |  0.0  |
# |   fence    | 51.04 |  63.1 |
# | fence-pole |  0.0  |  0.0  |
# |   person   |  69.0 | 82.97 |
# |    dog     | 51.63 | 60.72 |
# |    car     | 92.28 | 96.46 |
# |  bicycle   | 49.43 | 69.42 |
# |    tree    | 69.89 | 82.33 |
# | bald-tree  | 71.41 | 84.02 |
# | ar-marker  | 84.38 | 94.59 |
# |  obstacle  | 73.74 | 84.94 |
# +------------+-------+-------+
# 2022-10-29 14:15:06,910 - mmseg - INFO - Summary:
# 2022-10-29 14:15:06,911 - mmseg - INFO -
# +-------+-------+-------+
# |  aAcc |  mIoU |  mAcc |
# +-------+-------+-------+
# | 92.28 | 64.36 | 73.13 |
# +-------+-------+-------+
# 2022-10-29 14:15:06,911 - mmseg - INFO - Iter(val) [40]	aAcc: 0.9228, mIoU: 0.6436, mAcc: 0.7313, IoU.unlabeled: 0.0012, IoU.paved-area: 0.9519, IoU.dirt: 0.5263, IoU.grass: 0.9303, IoU.gravel: 0.8034, IoU.water: 0.8795, IoU.rocks: 0.5616, IoU.pool: 0.9642, IoU.vegetation: 0.7517, IoU.roof: 0.9175, IoU.wall: 0.7082, IoU.window: 0.6785, IoU.door: 0.0000, IoU.fence: 0.5104, IoU.fence-pole: 0.0000, IoU.person: 0.6900, IoU.dog: 0.5163, IoU.car: 0.9228, IoU.bicycle: 0.4943, IoU.tree: 0.6989, IoU.bald-tree: 0.7141, IoU.ar-marker: 0.8438, IoU.obstacle: 0.7374, Acc.unlabeled: 0.0013, Acc.paved-area: 0.9760, Acc.dirt: 0.6760, Acc.grass: 0.9641, Acc.gravel: 0.9146, Acc.water: 0.9328, Acc.rocks: 0.7292, Acc.pool: 0.9853, Acc.vegetation: 0.8592, Acc.roof: 0.9443, Acc.wall: 0.8322, Acc.window: 0.8187, Acc.door: 0.0000, Acc.fence: 0.6310, Acc.fence-pole: 0.0000, Acc.person: 0.8297, Acc.dog: 0.6072, Acc.car: 0.9646, Acc.bicycle: 0.6942, Acc.tree: 0.8233, Acc.bald-tree: 0.8402, Acc.ar-marker: 0.9459, Acc.obstacle: 0.8494
# 2022-10-29 14:15:18,823 - mmseg - INFO - Iter [6850/7200]	lr: 7.528e-04, eta: 0:06:00, time: 1.185, data_time: 0.421, memory: 18994, decode.pam_cam.loss_ce: 0.0938, decode.pam_cam.acc_seg: 95.3682, decode.pam.loss_ce: 0.0957, decode.pam.acc_seg: 95.3257, decode.cam.loss_ce: 0.0966, decode.cam.acc_seg: 95.2738, aux.loss_ce: 0.0675, aux.acc_seg: 92.7200, loss: 0.3537
# 2022-10-29 14:16:00,711 - mmseg - INFO - Iter [6900/7200]	lr: 6.685e-04, eta: 0:05:08, time: 0.838, data_time: 0.069, memory: 18994, decode.pam_cam.loss_ce: 0.1065, decode.pam_cam.acc_seg: 94.9669, decode.pam.loss_ce: 0.1086, decode.pam.acc_seg: 94.8859, decode.cam.loss_ce: 0.1107, decode.cam.acc_seg: 94.8049, aux.loss_ce: 0.0780, aux.acc_seg: 91.9754, loss: 0.4038
# 2022-10-29 14:16:45,872 - mmseg - INFO - Iter [6950/7200]	lr: 5.828e-04, eta: 0:04:16, time: 0.923, data_time: 0.150, memory: 18994, decode.pam_cam.loss_ce: 0.1027, decode.pam_cam.acc_seg: 94.9169, decode.pam.loss_ce: 0.1051, decode.pam.acc_seg: 94.8589, decode.cam.loss_ce: 0.1064, decode.cam.acc_seg: 94.7498, aux.loss_ce: 0.0739, aux.acc_seg: 91.9900, loss: 0.3881
# 2022-10-29 14:17:31,138 - mmseg - INFO - Exp name: pspnet_r50-d8_512x512_160k_ade20k.py
# 2022-10-29 14:17:31,138 - mmseg - INFO - Iter [7000/7200]	lr: 4.953e-04, eta: 0:03:25, time: 1.070, data_time: 0.297, memory: 18994, decode.pam_cam.loss_ce: 0.1077, decode.pam_cam.acc_seg: 94.9559, decode.pam.loss_ce: 0.1101, decode.pam.acc_seg: 94.8680, decode.cam.loss_ce: 0.1126, decode.cam.acc_seg: 94.7251, aux.loss_ce: 0.0787, aux.acc_seg: 91.9156, loss: 0.4091
# 2022-10-29 14:18:13,004 - mmseg - INFO - Iter [7050/7200]	lr: 4.056e-04, eta: 0:02:33, time: 0.837, data_time: 0.064, memory: 18994, decode.pam_cam.loss_ce: 0.0988, decode.pam_cam.acc_seg: 95.1697, decode.pam.loss_ce: 0.1013, decode.pam.acc_seg: 95.1030, decode.cam.loss_ce: 0.1026, decode.cam.acc_seg: 95.0430, aux.loss_ce: 0.0730, aux.acc_seg: 92.3461, loss: 0.3758
# 2022-10-29 14:18:58,089 - mmseg - INFO - Iter [7100/7200]	lr: 3.128e-04, eta: 0:01:42, time: 0.910, data_time: 0.139, memory: 18994, decode.pam_cam.loss_ce: 0.0966, decode.pam_cam.acc_seg: 95.1605, decode.pam.loss_ce: 0.0992, decode.pam.acc_seg: 95.0582, decode.cam.loss_ce: 0.1006, decode.cam.acc_seg: 94.9941, aux.loss_ce: 0.0701, aux.acc_seg: 92.3888, loss: 0.3665
# 2022-10-29 14:19:43,857 - mmseg - INFO - Iter [7150/7200]	lr: 2.150e-04, eta: 0:00:51, time: 1.006, data_time: 0.234, memory: 18994, decode.pam_cam.loss_ce: 0.1027, decode.pam_cam.acc_seg: 95.0885, decode.pam.loss_ce: 0.1053, decode.pam.acc_seg: 95.0191, decode.cam.loss_ce: 0.1060, decode.cam.acc_seg: 95.0076, aux.loss_ce: 0.0783, aux.acc_seg: 92.0070, loss: 0.3923
# 2022-10-29 14:20:25,881 - mmseg - INFO - Iter [7200/7200]	lr: 1.033e-04, eta: 0:00:00, time: 0.840, data_time: 0.067, memory: 18994, decode.pam_cam.loss_ce: 0.0989, decode.pam_cam.acc_seg: 95.2081, decode.pam.loss_ce: 0.1011, decode.pam.acc_seg: 95.1494, decode.cam.loss_ce: 0.1030, decode.cam.acc_seg: 95.0553, aux.loss_ce: 0.0707, aux.acc_seg: 92.5811, loss: 0.3738
# 2022-10-29 14:20:25,882 - mmseg - INFO - Saving checkpoint at 100 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 40/40, 8.7 task/s, elapsed: 5s, ETA:     0s2022-10-29 14:20:48,666 - mmseg - INFO - per class results:
# 2022-10-29 14:20:48,667 - mmseg - INFO -
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | unlabeled  |  0.14 |  0.15 |
# | paved-area |  95.0 | 97.42 |
# |    dirt    | 52.71 | 68.26 |
# |   grass    | 93.04 | 96.45 |
# |   gravel   | 79.98 | 91.17 |
# |   water    | 85.35 | 91.52 |
# |   rocks    | 55.89 | 71.67 |
# |    pool    | 96.62 | 98.54 |
# | vegetation |  74.4 | 85.37 |
# |    roof    |  91.9 | 94.66 |
# |    wall    | 70.85 | 82.89 |
# |   window   | 69.28 |  83.9 |
# |    door    |  0.0  |  0.0  |
# |   fence    | 50.65 | 61.93 |
# | fence-pole |  0.0  |  0.0  |
# |   person   | 69.16 | 82.72 |
# |    dog     | 53.05 | 60.01 |
# |    car     | 92.25 | 96.58 |
# |  bicycle   | 49.58 | 67.83 |
# |    tree    |  68.7 | 84.03 |
# | bald-tree  | 70.99 |  84.5 |
# | ar-marker  | 85.17 | 95.28 |
# |  obstacle  | 74.23 | 84.46 |
# +------------+-------+-------+
# 2022-10-29 14:20:48,667 - mmseg - INFO - Summary:
# 2022-10-29 14:20:48,667 - mmseg - INFO -
# +-------+------+-------+
# |  aAcc | mIoU |  mAcc |
# +-------+------+-------+
# | 92.15 | 64.3 | 73.02 |
# +-------+------+-------+
# 2022-10-29 14:20:48,667 - mmseg - INFO - Iter(val) [40]	aAcc: 0.9215, mIoU: 0.6430, mAcc: 0.7302, IoU.unlabeled: 0.0014, IoU.paved-area: 0.9500, IoU.dirt: 0.5271, IoU.grass: 0.9304, IoU.gravel: 0.7998, IoU.water: 0.8535, IoU.rocks: 0.5589, IoU.pool: 0.9662, IoU.vegetation: 0.7440, IoU.roof: 0.9190, IoU.wall: 0.7085, IoU.window: 0.6928, IoU.door: 0.0000, IoU.fence: 0.5065, IoU.fence-pole: 0.0000, IoU.person: 0.6916, IoU.dog: 0.5305, IoU.car: 0.9225, IoU.bicycle: 0.4958, IoU.tree: 0.6870, IoU.bald-tree: 0.7099, IoU.ar-marker: 0.8517, IoU.obstacle: 0.7423, Acc.unlabeled: 0.0015, Acc.paved-area: 0.9742, Acc.dirt: 0.6826, Acc.grass: 0.9645, Acc.gravel: 0.9117, Acc.water: 0.9152, Acc.rocks: 0.7167, Acc.pool: 0.9854, Acc.vegetation: 0.8537, Acc.roof: 0.9466, Acc.wall: 0.8289, Acc.window: 0.8390, Acc.door: 0.0000, Acc.fence: 0.6193, Acc.fence-pole: 0.0000, Acc.person: 0.8272, Acc.dog: 0.6001, Acc.car: 0.9658, Acc.bicycle: 0.6783, Acc.tree: 0.8403, Acc.bald-tree: 0.8450, Acc.ar-marker: 0.9528, Acc.obstacle: 0.8446

# %%
# !python tools/test.py configs/pspnet/pspnet_r50-d8_512x512_160k_ade20k.py work_dirs/pspnet_r50-d8_512x512_160k_ade20k/latest.pth --opacity 1 --eval mIoU --show-dir out
# Out:
# 2022-10-29 14:21:04,761 - mmseg - INFO - Multi-processing start method is `None`
# 2022-10-29 14:21:04,761 - mmseg - INFO - OpenCV num_threads is `32
# 2022-10-29 14:21:04,762 - mmseg - INFO - Loaded 40 images
# /home/rongjian/yolov7-main/wandb/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:236: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# load checkpoint from local path: work_dirs/pspnet_r50-d8_512x512_160k_ade20k/latest.pth
# tools/test.py:265: UserWarning: SyncBN is only supported with DDP. To be compatible with DP, we convert SyncBN to BN. Please use dist_train.sh which can avoid this error.
#   'SyncBN is only supported with DDP. To be compatible with DP, '
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 40/40, 0.4 task/s, elapsed: 103s, ETA:     0sper class results:
#
# +------------+-------+-------+
# |   Class    |  IoU  |  Acc  |
# +------------+-------+-------+
# | unlabeled  |  0.14 |  0.15 |
# | paved-area |  95.0 | 97.42 |
# |    dirt    | 52.71 | 68.26 |
# |   grass    | 93.04 | 96.45 |
# |   gravel   | 79.98 | 91.17 |
# |   water    | 85.35 | 91.52 |
# |   rocks    | 55.89 | 71.67 |
# |    pool    | 96.62 | 98.54 |
# | vegetation |  74.4 | 85.37 |
# |    roof    |  91.9 | 94.66 |
# |    wall    | 70.85 | 82.89 |
# |   window   | 69.28 |  83.9 |
# |    door    |  0.0  |  0.0  |
# |   fence    | 50.65 | 61.93 |
# | fence-pole |  0.0  |  0.0  |
# |   person   | 69.16 | 82.72 |
# |    dog     | 53.05 | 60.01 |
# |    car     | 92.25 | 96.58 |
# |  bicycle   | 49.58 | 67.83 |
# |    tree    |  68.7 | 84.03 |
# | bald-tree  | 70.99 |  84.5 |
# | ar-marker  | 85.17 | 95.28 |
# |  obstacle  | 74.23 | 84.46 |
# +------------+-------+-------+
# Summary:
#
# +-------+------+-------+
# |  aAcc | mIoU |  mAcc |
# +-------+------+-------+
# | 92.15 | 64.3 | 73.02 |
# +-------+------+-------+

# %%
import cv2
import matplotlib.pyplot as plt
path = '/home/rongjian/yolov7-main/wandb/datas/images/validation'
files = os.listdir(path)
# 使用matplotlib展示多张图片
num = len(files)
j = 0
while j<len(files):
    
    for i in range(0,3):
        if i==2:
            img = cv2.imread('/home/rongjian/yolov7-main/wandb/mmsegmentation/out'+'/'+files[j][:-4]+'.jpg')
            title="predict"
        #行，列，索引
            plt.subplot(1,3,i+1)
        #plt.figure(figsize=(2, 2))
            plt.imshow(img)
            plt.title(title,fontsize=8)
            plt.xticks([])
            plt.yticks([])
    
        elif i==1:
            img = cv2.imread('/home/rongjian/yolov7-main/wandb/RGB_color_image_masks/RGB_color_image_masks'+'/'+files[j][:-4]+'.png')
            title="ground ture"
        #行，列，索引
            plt.subplot(1,3,i+1)
            #plt.figure(figsize=(2,2))
            plt.imshow(img)
            plt.title(title,fontsize=8)
            plt.xticks([])
            plt.yticks([])
        elif i==0:
            img = cv2.imread('/home/rongjian/yolov7-main/wandb/datas/images/validation'+'/'+files[j][:-4]+'.jpg')
            title="image"
        #行，列，索引
            plt.subplot(1,3,i+1)
            #plt.figure(figsize=(2, 2))
            plt.imshow(img)
            plt.title(title,fontsize=8)
            plt.xticks([])
            plt.yticks([])   
    plt.show()
    j = j+1
